# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Exponential growth modell $$\frac{dP(t)}{dt}= aP(t)$$

# %% [markdown]
# ### Exponential growth function $$P(t) = b*e^{at}$$

# %%
t = np.arange(1, 100)
a = 0.1
b = 1
y= b*np.exp(a*(t))

plt.plot(t,y)
plt.show()

# %% [markdown]
# ### Logistic differential equation $$\frac{dP(t)}{dt} = aP(t)(1-\frac{P(t)}{K})$$

# %% [markdown]
# ### Logistic growth function$$P(t)=\frac{K}{(1+e^{-a(t-b)})}$$

# %%
t = np.arange(0, 100)
K = 100
a = 0.1
b = 50


y = K/(1+np.exp(-a*(x-b)))

plt.plot(x,y)
plt.show()

# %% [markdown]
# ### Bi-logistic growth

# %% [markdown]
# $$N_{1}(t) = N_{1}(t)+N_{2}(t)$$$$ $$$$N_{1}(t) = \frac{K_{1}}{1+e^{-a_{1}(t-b_{1})}}$$ $$$$ $$N_{2}(t) = \frac{K_{2}}{1+e^{-a_{2}(t-b_{2})}}$$

# %% [markdown]
# $$N(t) = \frac{K_{1}}{1+e^{-a_{1}(t-b_{1})}} + \frac{K_{2}}{1+e^{-a_{2}(t-b_{2})}}$$

# %%
t = np.arange(0, 100)

K1 = 100
a1 = 0.3
b1 = 50

K2 = 400
a2 = 0.6
b2 = 80

y = K1/(1+np.exp(-a1*(x-b1))) + \
    K2/(1+np.exp(-a2*(x-b2)))

plt.plot(t,y)
plt.show()
